# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
df = pd.read_csv("../data/processed/final.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            3         1       3
# 2            4         1       1
# 3            5         0       3
# 4            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 1                        Heikkinen, Miss. Laina  female  26.0      0      0
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 3                      Allen, Mr. William Henry    male  35.0      0      0
# 4                              Moran, Mr. James    male  28.0      0      0
#
#              Ticket     Fare    Cabin Embarked
# 0         A/5 21171   7.2500  B96 B98        S
# 1  STON/O2. 3101282   7.9250  B96 B98        S
# 2            113803  53.1000     C123        S
# 3            373450   8.0500  B96 B98        S
# 4            330877   8.4583  B96 B98        Q

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  561 non-null    int64
#  1   Survived     561 non-null    int64
#  2   Pclass       561 non-null    int64
#  3   Name         561 non-null    str
#  4   Sex          561 non-null    str
#  5   Age          561 non-null    float64
#  6   SibSp        561 non-null    int64
#  7   Parch        561 non-null    int64
#  8   Ticket       561 non-null    str
#  9   Fare         561 non-null    float64
#  10  Cabin        561 non-null    str
#  11  Embarked     561 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 52.7 KB

# %%
msno.heatmap(df)
plt.show()
# Out:
# /home/zoyafatima/Desktop/Hestabit Training /Week-6/Day-1/venv/lib/python3.12/site-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /home/zoyafatima/Desktop/Hestabit Training /Week-6/Day-1/venv/lib/python3.12/site-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
df.hist(figsize=(12,10))
plt.show()

# %%
sns.countplot(x="Survived", data=df)
plt.title("Target Distribution")
plt.show()

# %%
df.shape
# Out:
# (561, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    400
# 1    161
# Name: count, dtype: int64
